# %%
import pysift
import numpy as np
import cv2
# import pysift

import logging

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
img1 = cv2.imread('coca2.jpg',0)
img2 = cv2.imread('coca1.jpg',0)


plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.show()

plt.figure(figsize=(20,10))
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
surf = cv2.xfeatures2d.SURF_create()

# find the keypoints and descriptors with SURF
kp1, des1 = surf.detectAndCompute(img1,None)
kp2, des2 = surf.detectAndCompute(img2,None)

# no.of keypoints 
print(len(des1))
print(len(des2))

# BFMatcher with default params
bf = cv2.BFMatcher()
matches = bf.knnMatch(des1,des2, k=2)

# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])

print("matches ")
print(len(good))

# cv.drawMatchesKnn expects list of lists as matches
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
# cv.imwrite('sift_keypoints.jpg',img3)

plt.figure(figsize=(20,10))
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-e1c1c6535b32> in <module>
# ----> 1 surf = cv2.xfeatures2d.URF_OCL()
#       2
#       3 # find the keypoints and descriptors with SURF
#       4 kp1, des1 = surf.detectAndCompute(img1,None)
#       5 kp2, des2 = surf.detectAndCompute(img2,None)
#
# AttributeError: module 'cv2.xfeatures2d' has no attribute 'URF_OCL'

# %%
surf.findMaximaInLayer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-3cafa90da4b7> in <module>
# ----> 1 surf.findMaximaInLayer()
#
# AttributeError: 'cv2.xfeatures2d_SURF' object has no attribute 'findMaximaInLayer'
